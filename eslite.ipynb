# %%
import requests
import json
import os
import pandas as pd

if not os.path.exists('./WebCrawle-eslite'):
    os.mkdir('./WebCrawle-eslite')

url = 'https://athena.eslite.com/api/v2/search?q=python&final_price=0,&sort=_weight_+desc&size=20&start=0'
userAgent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36 Edg/92.0.902.67'

headers = {
    'Referer': 'https://www.eslite.com/Search?keyword=python&final_price=0%2C&sort=_weight_+desc&size=20&start=0'}
res = requests.get(url, headers=headers)
jsonData = json.loads(res.text)
tempid = jsonData['hits']['hit']
bookname=[]
bookURL=[]
bookauthor=[]
booksupplier=[]
bookisbn13=[]
picture=[]

for i in range(0, 20):
    bookid = tempid[i]['id']
    book_URL = tempid[i]['fields']['url']
    bookURL.append(book_URL)
    # picture='https://s.eslite.dev'+tempid[i]['fields']['product_photo_url']
    newurl = 'https://athena.eslite.com/api/v1/products/{}'.format(bookid)
    newheaders = {'Referer': book_URL}
    newres = requests.get(newurl, headers=newheaders)
    newData = json.loads(newres.text)
    book_name = newData['name']  # 書名
    bookname.append(book_name)
    book_author = newData['auth']  # 作者
    bookauthor.append(book_author)
    book_supplier = newData['supplier']  # 出版社
    booksupplier.append(book_supplier)
    book_isbn13 = newData['isbn13']  # ISBN
    bookisbn13.append(book_isbn13)
    bookphotos = newData['photos']
    try:
        book_picture = 'https://s.eslite.dev' + bookphotos[0]['large_path']  # 書圖片
        picture.append(book_picture)
    except IndexError:
        picture.append('0')
eslite =pd.DataFrame({'書名': bookname,'書籍網址': bookURL,'作者': bookauthor,'出版社': booksupplier, 'ISBN': bookisbn13,'圖片網址': picture})
eslite.to_csv("./eslite.csv",encoding='utf-8-sig',index=False)

# %%
eslite
# Out:
#                                                    書名  \
# 0   Album Of The Soundtrack Of The Trailer Of The ...
# 1   Monty Python's Total Rubbish: The Complete Col...
# 2                                  Monty Python Sings
# 3                                    用Python學程式設計運算思維
# 4                                       Python資料可視化攻略
# 5                                  Python機器學習 下 (第3版)
# 6                                  Python機器學習 上 (第3版)
# 7                  Python自動化的樂趣: 搞定重複瑣碎&單調無聊的工作 (第2版)
# 8                                      架構模式: 使用Python
# 9                              Python非同步設計: 使用Asyncio
# 10       Python X Network一拍即合: 自動化、程式化和DevOps的一站式解決方案
# 11                    東京大學資料科學家養成全書: 使用Python動手學習資料分析
# 12                               經典電腦科學問題解析: 使用Python
# 13                      精通Python: 運用簡單的套件進行現代運算 (第2版)
# 14            Python程式設計的樂趣: 範例實作與專題研究的20堂程式設計課 (第2版)
# 15               文科生也能懂的Python程式設計: 用Python寫出高中數學解題程式
# 16                                   非監督式學習: 使用Python
# 17                                   最新Python程式設計實例入門
# 18                             增壓的Python: 讓程式碼進化到全新境界
# 19                                       Python程式學習進階
#
#                                                  書籍網址  \
# 0     https://www.eslite.com/product/1004123082875006
# 1     https://www.eslite.com/product/1004305972396411
# 2     https://www.eslite.com/product/1004128571081642
# 3     https://www.eslite.com/product/1001113692690584
# 4   https://www.eslite.com/product/100111369268201...
# 5     https://www.eslite.com/product/1001120322877376
# 6     https://www.eslite.com/product/1001120322872894
# 7     https://www.eslite.com/product/1001113692869108
# 8     https://www.eslite.com/product/1001133102866550
# 9     https://www.eslite.com/product/1001133102866300
